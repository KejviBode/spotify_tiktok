# %%
import os
import psycopg2
import s3fs
import csv
import datetime as dt
from s3fs import S3FileSystem
from dotenv import load_dotenv
from psycopg2.extensions import connection

# %%
BUCKET = "c7-spotify-tiktok-output"

load_dotenv()
def get_db_connection() -> connection:
    """Connects to the database"""
    try:
        conn = psycopg2.connect(
            user=os.environ["DB_USER"],
            host=os.environ["DB_HOST"],
            database=os.environ["DB_NAME"],
            password=os.environ['DB_PASSWORD'],
            port=os.environ['DB_PORT']
        )
        return conn
    except Exception as err:
        print(err)
        print("Error connecting to database.")

conn = get_db_connection()

# %%
def get_list_from_sql(conn: connection, column_name: str, table_name: str) -> list:

    sql = f"""SELECT {column_name} FROM {table_name};"""
    with conn.cursor() as curs:
        curs.execute(sql, (column_name, table_name))
        tracks = curs.fetchall()
    return [track[0] for track in tracks]

# %%
get_list_from_sql(conn, "track_name", "track")
# Out:
# ['Ella Baila Sola',
#  'un x100to',
#  'La Bebe - Remix',
#  'Cupid - Twin Ver.',
#  'Flowers',
#  'Daylight',
#  'Kill Bill',
#  'As It Was',
#  'Acróstico',
#  'TQG',
#  'Classy 101',
#  'Tattoo',
#  'BESO',
#  "Creepin' (with The Weeknd & 21 Savage)",
#  'Die For You (with Ariana Grande) - Remix',
#  'Yandel 150',
#  'Calm Down (with Selena Gomez)',
#  'See You Again (feat. Kali Uchis)',
#  'PRC',
#  'El Azul',
#  'Cha Cha Cha',
#  "Boy's a Liar Pt. 2",
#  'Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni Long)',
#  'Anti-Hero',
#  'Like Crazy',
#  'Last Night',
#  'All My Life (feat. J. Cole)',
#  'Die For You',
#  'I Wanna Be Yours',
#  "I'm Good (Blue)",
#  'Angels Like You',
#  'AMG',
#  'Here With Me',
#  'golden hour',
#  'Until I Found You (with Em Beihold) - Em Beihold Version',
#  'Shakira: Bzrp Music Sessions, Vol. 53',
#  'Moonlight',
#  'Another Love',
#  'Starboy',
#  'Unholy (feat. Kim Petras)',
#  'Hey Mor',
#  'Cruel Summer',
#  "I Ain't Worried",
#  'La Bachata',
#  'Por las Noches',
#  'People',
#  'Yellow',
#  'Frágil',
#  'Mockingbird',
#  'MATHEMATICAL DISRESPECT',
#  'money trees',
#  'die (sped up)',
#  'Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version',
#  'Push Up (Original Mix)',
#  'Beat Automotivo Tan Tan Tan Viral',
#  'cupid',
#  'What It Is - Solo Version',
#  'All Eyes on Me',
#  '꽃',
#  'Aesthetic',
#  'Baby you (Baby you Ver.)',
#  '2 Hielos',
#  'MON LOVE OHO',
#  'THIS YEAR (Blessings)',
#  'MTG MALDIÇÃO ETERNA 1.0 (Slowed)',
#  'Chill Vibes',
#  'Bounce When She Walk',
#  'Moulaga - Sped up',
#  "girls like me don't cry (sped up)",
#  'One Wish',
#  'Its such a beautiful day',
#  'Maria Maria (feat. The Product G&B) (sped up)',
#  'Blicky',
#  'Keep Dat Nigga',
#  'OMG',
#  'motorcycle dududu',
#  'Laughing',
#  'LA PATITA LULÚ',
#  'Collide (more sped up)',
#  'Obsessed With You x All About Him',
#  'AMARGURA',
#  'XTAYALIVE 2',
#  'Macho Preferido',
#  "Can't Take My Eyes Off You - Original Extended Version",
#  'Coconut Mall (From "Mario Kart Wii")',
#  'Sunrise',
#  'Funny Song',
#  'Rodeo (Remix)',
#  'moulaga',
#  'El Gordo Trae El Mando',
#  'Monkeys Spinning Monkeys',
#  'Happy',
#  'Why Do I Love You',
#  'La Lecon Particuliere - Bof La Lecon Particuliere',
#  'Tomioka Dropping July 6th',
#  'Just A Girl',
#  'One Side',
#  'Niña Bonita',
#  'Love You So',
#  'Bombastic Side Eye Criminal Offensive Side Eye',
#  'all of the lights',
#  'Billie bossa nova X west coast lostten4ever',
#  'Calm Down',
#  'El Pescuezo Del Pollo (En Vivo)',
#  'Peaches',
#  'Happy Birthday',
#  'MIENTRAS ME CURO DEL CORA',
#  'Da Girls']

# %%
get_list_from_sql(conn, "spotify_name", "artist")
# Out:
# [('Eslabon Armado',),
#  ('Peso Pluma',),
#  ('Grupo Frontera',),
#  ('Bad Bunny',),
#  ('Yng Lvcas',),
#  ('FIFTY FIFTY',),
#  ('Miley Cyrus',),
#  ('David Kushner',),
#  ('SZA',),
#  ('Harry Styles',),
#  ('Shakira',),
#  ('KAROL G',),
#  ('Feid',),
#  ('Young Miko',),
#  ('Loreen',),
#  ('ROSALÍA',),
#  ('Rauw Alejandro',),
#  ('Metro Boomin',),
#  ('The Weeknd',),
#  ('21 Savage',),
#  ('Ariana Grande',),
#  ('Yandel',),
#  ('Rema',),
#  ('Selena Gomez',),
#  ('Tyler, The Creator',),
#  ('Kali Uchis',),
#  ('Natanael Cano',),
#  ('Junior H',),
#  ('Käärijä',),
#  ('PinkPantheress',),
#  ('Ice Spice',),
#  ('Kodak Black',),
#  ('NLE Choppa',),
#  ('Jimin',),
#  ('JVKE',),
#  ('Muni Long',),
#  ('Taylor Swift',),
#  ('Morgan Wallen',),
#  ('Lil Durk',),
#  ('J. Cole',),
#  ('Arctic Monkeys',),
#  ('David Guetta',),
#  ('Bebe Rexha',),
#  ('Gabito Ballesteros',),
#  ('d4vd',),
#  ('Stephen Sanchez',),
#  ('Em Beihold',),
#  ('Bizarrap',),
#  ('Tom Odell',),
#  ('Daft Punk',),
#  ('Sam Smith',),
#  ('Kim Petras',),
#  ('Ozuna',),
#  ('OneRepublic',),
#  ('Manuel Turizo',),
#  ('Libianca',),
#  ('Coldplay',),
#  ('Yahritza Y Su Esencia',),
#  ('Eminem',),
#  ('Lil Mabu',),
#  ('Kendrick Lamar',),
#  ('Jay Rock',),
#  ('lucidbeatz',),
#  ('Key Kelly',),
#  ('sped up 8282',),
#  ('Creeds',),
#  ('WZ Beat',),
#  ('Sionel el de la Melodia',),
#  ('Doechii',),
#  ('Dj Belite',),
#  ('DNDM',),
#  ('달콤한꿈',),
#  ('Tollan Kim',),
#  ('Kudasaibeats',),
#  ('Christina Aguilera',),
#  ('King Savagge',),
#  ('Jere Klein',),
#  ('Liamsi',),
#  ('Victor Thompson',),
#  ("Ehis 'D' Greatest",),
#  ('DJ GLK',),
#  ('MC LIPEX',),
#  ('Dj luis do grau',),
#  ('Ohboyprince',),
#  ('Mykfresh',),
#  ('GwallaGangSpec',),
#  ("Heuss L'enfoiré",),
#  ('Jul',),
#  ('thuy',),
#  ('Ray J',),
#  ('Love Unlimited',),
#  ('Santana',),
#  ('The Product G&B',),
#  ('Fresh X Reckless',),
#  ('Icandy',),
#  ('White Gangster',),
#  ('Funny Minions Guys',),
#  ('Gianluca Marino',),
#  ('Kalanera',),
#  ('Tatiana',),
#  ('Justine Skye',),
#  ('Tyga',),
#  ('Green Neon DJ',),
#  ('Kanii',),
#  ('9lives',),
#  ('Zé Felipe',),
#  ('Ana Castela',),
#  ('Luan Pereira',),
#  ('Boys Town Gang',),
#  ('Arcade Player',),
#  ('Official Sound Studio',),
#  ('Cavendish Music',),
#  ('Lah Pat',),
#  ('Flo Milli',),
#  ('Chino Pacas',),
#  ('Kevin MacLeod',),
#  ('Pharrell Williams',),
#  ('Westlife',),
#  ('Francis Lai',),
#  ('Christian Gaubert',),
#  ('Jay Eazy',),
#  ('No Doubt',),
#  ('Iyanya',),
#  ('Sean Paul',),
#  ('The King Khan & BBQ Show',),
#  ('Aurelio Casadiego',),
#  ('Kanye West',),
#  ('The Ivy',),
#  ('Los Juniors de La Montaña',),
#  ('Jack Black',),
#  ('Jovanie',),
#  ('Ciara',)]
